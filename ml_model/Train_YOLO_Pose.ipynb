# %% [markdown]
# # Train YOLO Pose Model (Bee Dataset)
#
# This notebook trains a YOLO pose estimation model using data in `./labeled-data` (YOLO v1.0 pose labels).

# %% [markdown]
# ## 1) Install/Import Dependencies

# %%
# If needed, uncomment to install Ultralytics
# %pip install -q ultralytics pyyaml

import os
from pathlib import Path

from ultralytics import YOLO

# %% [markdown]
# ## 2) Configure Paths

# %%
ROOT = Path.cwd()
DATA_DIR = ROOT / "labeled-data"
IMAGES_DIR = DATA_DIR / "images"
LABELS_DIR = DATA_DIR / "labels"
DATA_YAML = DATA_DIR / "data.yaml"
OUTPUT_DIR = ROOT / "output"
OUTPUT_DIR.mkdir(exist_ok=True)
MODEL_OUTPUT = ROOT / "ml_runs" / "pose"
# PRETRAINED_WEIGHTS = MODEL_OUTPUT / "bee_pose" / "weights" / "best.pt"
PRETRAINED_WEIGHTS = "yolo11s-pose.pt"

assert DATA_DIR.exists(), f"Missing dataset folder: {DATA_DIR}"
assert IMAGES_DIR.exists(), f"Missing images folder: {IMAGES_DIR}"
assert LABELS_DIR.exists(), f"Missing labels folder: {LABELS_DIR}"
assert DATA_YAML.exists(), f"Missing YAML file: {DATA_YAML}"
#assert PRETRAINED_WEIGHTS.exists(), f"Missing pretrained weights: {PRETRAINED_WEIGHTS}"

print(f"Workspace root: {ROOT}")
print(f"Dataset folder: {DATA_DIR}")
# Out:
# Workspace root: c:\Users\bee-ops\code\ChoiceAssay\ml_model
# Dataset folder: c:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data

# %% [markdown]
# ## 3a) Remove images without labels

# %%
# Remove any images that don't have corresponding labels
for img_file in IMAGES_DIR.glob("*.png"):
    label_file = LABELS_DIR / img_file.with_suffix(".txt").name
    if not label_file.exists():
        print(f"Removing image without label: {img_file}")
        img_file.unlink()

# %% [markdown]
# ## 3b) Redo autosplit if required

# %%
# Autosplit the labeled-data into train, test, and validation sets
from ultralytics.data.split import autosplit


def redo_autosplit():
    # Ensure that the autosplit is run in the labeled-data directory, but return to the base directory
    # afterwards so that YOLO runs properly
    path = Path.cwd()
    if path.parts[-1] != "labeled-data":
        labeled_data_path = path / "labeled-data"
        os.chdir(labeled_data_path)
    else:
        path = path.parent
    autosplit(path=".", weights=(0.8, 0.12, 0.08))
    os.chdir(path)

#redo_autosplit()
# Out:
# Autosplitting images from .
# : 100% ━━━━━━━━━━━━ 738/738 4.6Kit/s 0.2s0.2s

# %% [markdown]
# ## 4) Train YOLO Pose

# %%
IMGSZ = 1640 // 4

print(f"Using device training YOLO pose model: {PRETRAINED_WEIGHTS}")

model = YOLO(PRETRAINED_WEIGHTS)
results = model.train(data=str(DATA_YAML), epochs=300, imgsz=IMGSZ, project=MODEL_OUTPUT)
results
# Out:
# Using device training YOLO pose model: yolo11s-pose.pt
# New https://pypi.org/project/ultralytics/8.4.27 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.21  Python-3.13.12 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=410, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=c:\Users\bee-ops\code\ChoiceAssay\ml_model\ml_runs\pose, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\bee-ops\code\ChoiceAssay\ml_model\ml_runs\pose\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[7, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1107954  ultralytics.nn.modules.head.Pose             [1, [7, 3], 16, None, [128, 256, 512]]
# YOLO11s-pose summary: 197 layers, 9,716,338 parameters, 9,716,322 gradients, 22.5 GFLOPs
#
# Transferred 505/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING imgsz=[410] must be multiple of max stride 32, updating to [416]
# train: Fast image access  (ping: 0.00.0 ms, read: 165.1198.3 MB/s, size: 58.4 KB)
# train: Scanning C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\labels\train... 562 images, 29 backgrounds, 4 corrupt: 100% ━━━━━━━━━━━━ 591/591 2.1Kit/s 0.3s<0.2s
# train: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\images\train\right_12-06-2024_12-58-11_img48.png: ignoring corrupt image/label: negative class labels or coordinate [-0.020642 -0.020642]
# train: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\images\train\right_19-06-2024_19-33-26_img42.png: ignoring corrupt image/label: negative class labels or coordinate [-0.011468 -0.011468]
# train: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\images\right_12-06-2024_12-58-11_img48.png: ignoring corrupt image/label: negative class labels or coordinate [-0.020642 -0.020642]
# train: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\images\right_19-06-2024_19-33-26_img42.png: ignoring corrupt image/label: negative class labels or coordinate [-0.011468 -0.011468]
# train: New cache created: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\labels\train.cache
# WARNING No 'flip_idx' array defined in data.yaml, disabling 'fliplr' and 'flipud' augmentations.
# val: Fast image access  (ping: 0.00.0 ms, read: 75.136.1 MB/s, size: 54.6 KB)
# val: Scanning C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\labels\train... 87 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 89/89 2.2Kit/s 0.0s
# val: New cache created: C:\Users\bee-ops\code\ChoiceAssay\ml_model\labeled-data\bee_pose_yolo_sw_updated\labels\train.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Plotting labels to C:\Users\bee-ops\code\ChoiceAssay\ml_model\ml_runs\pose\train2\labels.jpg...
# Image sizes 416 train, 416 val
# Using 0 dataloader workers
# Logging results to C:\Users\bee-ops\code\ChoiceAssay\ml_model\ml_runs\pose\train2
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       1/300         0G      2.362      8.988     0.7219      2.597      2.022         18        416: 84% ━━━━━━━━━━── 31/37 1.2it/s 1:55<4.9ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 print(f"Using device training YOLO pose model: {PRETRAINED_WEIGHTS}")
#       5 model = YOLO(PRETRAINED_WEIGHTS)
# ----> 6 results = model.train(data=str(DATA_YAML), epochs=300, imgsz=IMGSZ, project=MODEL_OUTPUT)
#       7 results
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\engine\model.py:777, in Model.train(self, trainer, **kwargs)
#     774     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     775     self.model = self.trainer.model
# --> 777 self.trainer.train()
#     778 # Update model and cfg after training
#     779 if RANK in {-1, 0}:
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\engine\trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\engine\trainer.py:436, in BaseTrainer._do_train(self)
#     434     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     435 else:
# --> 436     loss, self.loss_items = self.model(batch)
#     437 self.loss = loss.sum()
#     438 if RANK != -1:
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\tasks.py:334, in BaseModel.loss(self, batch, preds)
#     331     self.criterion = self.init_criterion()
#     333 if preds is None:
# --> 334     preds = self.forward(batch["img"])
#     335 return self.criterion(preds, batch)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)     76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\modules\batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File c:\Users\bee-ops\code\ChoiceAssay\.venv\Lib\site-packages\torch\nn\functional.py:2822, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2819 if training:
#    2820     _verify_batch_size(input.size())
# -> 2822 return torch.batch_norm(
#    2823     input,
#    2824     weight,
#    2825     bias,
#    2826     running_mean,
#    2827     running_var,
#    2828     training,
#    2829     momentum,
#    2830     eps,
#    2831     torch.backends.cudnn.enabled,
#    2832 )
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5) Validate and Export

# %%
metrics = model.val(data=str(DATA_YAML))
metrics

# %%
best_model = Path("./ml_runs/pose/bee_pose/weights/best.pt")
print("Best model path:", best_model)

# Optional exports:
model.export(format="ncnn")
# model.export(format='torchscript')

# %% [markdown]
# ## 6) Run Best Model on Arbitrary Image Directory
#
# Use the helper below to run inference with `best.pt` on any folder of images and save annotated output images.

# %%
def run_best_pose_on_image_dir(
    image_dir: str | Path,
    model_path: Path = None,
    output_dir: Path = OUTPUT_DIR,
    conf: float = 0.25,
    imgsz: int = 448,
) -> Path:
    """Run best.pt on all images in a directory and save annotated outputs.

    Args:
        image_dir: Directory containing input images.
        model_path: Path to weights. Defaults to PRETRAINED_WEIGHTS.
        output_dir: Directory to write annotated images. Defaults to OUTPUT_DIR.
        conf: Confidence threshold for predictions.
        imgsz: Inference image size.

    Returns:
        Path to the directory containing saved annotated images.
    """
    image_dir = Path(image_dir).expanduser().resolve()
    if model_path is None:
        model_path = PRETRAINED_WEIGHTS
    model_path = Path(model_path).expanduser().resolve()

    output_dir = Path(output_dir).expanduser().resolve()

    if not image_dir.exists() or not image_dir.is_dir():
        raise FileNotFoundError(f"Image directory not found: {image_dir}")
    if not model_path.exists():
        raise FileNotFoundError(f"Model weights not found: {model_path}")

    image_exts = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".webp"}
    image_files = [p for p in sorted(image_dir.iterdir()) if p.suffix.lower() in image_exts]
    if not image_files:
        raise ValueError(f"No supported images found in: {image_dir}")

    output_dir.parent.mkdir(parents=True, exist_ok=True)

    infer_model = YOLO(model_path)
    infer_model.predict(
        source=str(image_dir),
        conf=conf,
        imgsz=imgsz,
        save=True,
        project=str(output_dir.parent),
        name=output_dir.name,
        exist_ok=True,
    )

    print(f"Annotated images saved to: {output_dir}")
    return output_dir


# Example usage:
run_best_pose_on_image_dir(image_dir=IMAGES_DIR,
                           model_path=PRETRAINED_WEIGHTS)
